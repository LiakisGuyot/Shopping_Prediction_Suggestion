# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# <h1 style="color:blue;"> Toy Example </h1>

# %%
dataset = [['Lait', 'Oignon', 'Noix', 'Haricots Rouges', 'Oeufs', 'Yaourt'],
           ['Aneth', 'Oignon', 'Noix', 'Haricots Rouges', 'Oeufs', 'Yaourt'],
           ['Lait', 'Pomme', 'Haricots Rouges', 'Oeufs'],
           ['Lait', 'Maïs', 'Haricots Rouges', 'Yaourt'],
           ['Maïs', 'Oignon', 'Haricots Rouges', 'Glace', 'Oeufs']]


transactions = TransactionEncoder()
transactions_array = transactions.fit(dataset).transform(dataset)
df_train = pd.DataFrame(transactions_array, columns=transactions.columns_)
df_train.head(3)
# Out:
#    Aneth  Glace  Haricots Rouges   Lait   Maïs   Noix  Oeufs  Oignon  Pomme  \
# 0  False  False             True   True  False   True   True    True  False
# 1   True  False             True  False  False   True   True    True  False
# 2  False  False             True   True  False  False   True   False   True
#
#    Yaourt
# 0    True
# 1    True
# 2   False

# %% [markdown]
# ### Recherche de motifs fréquents

# %%
frequent_itemsets_train = apriori(df_train, min_support=0.5, use_colnames=True)
frequent_itemsets_train
# Out:
#     support                          itemsets
# 0       1.0                 (Haricots Rouges)
# 1       0.6                            (Lait)
# 2       0.8                           (Oeufs)
# 3       0.6                          (Oignon)
# 4       0.6                          (Yaourt)
# 5       0.6           (Lait, Haricots Rouges)
# 6       0.8          (Oeufs, Haricots Rouges)
# 7       0.6         (Oignon, Haricots Rouges)
# 8       0.6         (Yaourt, Haricots Rouges)
# 9       0.6                   (Oeufs, Oignon)
# 10      0.6  (Oeufs, Oignon, Haricots Rouges)

# %%
frequent_itemsets_train[frequent_itemsets_train['itemsets'].astype(str).str.contains("Lait")]
# Out:
#    support                 itemsets
# 1      0.6                   (Lait)
# 5      0.6  (Lait, Haricots Rouges)

# %% [markdown]
# ### Recherche des règles d'association

# %%
from mlxtend.frequent_patterns import association_rules

# %%
training_rules = association_rules(frequent_itemsets_train, metric="confidence", min_threshold=0.7)
training_rules.sort_values(by=['confidence','lift'],ascending=False).iloc[:,:7]
# Out:
#                   antecedents                consequents  antecedent support  \
# 6                    (Oignon)                    (Oeufs)                 0.6
# 9   (Oignon, Haricots Rouges)                    (Oeufs)                 0.6
# 11                   (Oignon)   (Oeufs, Haricots Rouges)                 0.6
# 0                      (Lait)          (Haricots Rouges)                 0.6
# 1                     (Oeufs)          (Haricots Rouges)                 0.8
# 3                    (Oignon)          (Haricots Rouges)                 0.6
# 4                    (Yaourt)          (Haricots Rouges)                 0.6
# 7             (Oeufs, Oignon)          (Haricots Rouges)                 0.6
# 2           (Haricots Rouges)                    (Oeufs)                 1.0
# 5                     (Oeufs)                   (Oignon)                 0.8
# 8    (Oeufs, Haricots Rouges)                   (Oignon)                 0.8
# 10                    (Oeufs)  (Oignon, Haricots Rouges)                 0.8
#
#     consequent support  support  confidence  lift
# 6                  0.8      0.6        1.00  1.25
# 9                  0.8      0.6        1.00  1.25
# 11                 0.8      0.6        1.00  1.25
# 0                  1.0      0.6        1.00  1.00
# 1                  1.0      0.8        1.00  1.00
# 3                  1.0      0.6        1.00  1.00
# 4                  1.0      0.6        1.00  1.00
# 7                  1.0      0.6        1.00  1.00
# 2                  0.8      0.8        0.80  1.00
# 5                  0.6      0.6        0.75  1.25
# 8                  0.6      0.6        0.75  1.25
# 10                 0.6      0.6        0.75  1.25

# %% [markdown]
# <h1 style="color:blue;"> Market Kaggle Data Example </h1>

# %%
commandes=pd.read_csv('./order_products__prior.csv',sep=',')
commandes.head(5)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
commandes.shape
# Out:
# (32434489, 4)

# %%
produits=pd.read_csv('./products.csv',sep=',')
produits.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
produits.shape
# Out:
# (49688, 4)

# %% [markdown]
# ## Préparation des données

# %% [markdown]
# ### Sélection des commandes les plus importantes

# %%
selected_c=100000
commandes_counts = commandes.groupby('order_id')['product_id'].count().reset_index().rename(
    columns = {'product_id':'frequence'})
commandes_counts = commandes_counts.sort_values('frequence', ascending=False)[:selected_c].reset_index(drop=True)
commandes_counts.head(10)
# Out:
#    order_id  frequence
# 0   1564244        145
# 1    790903        137
# 2     61355        127
# 3   2970392        121
# 4   2069920        116
# 5   3308010        115
# 6   2753324        114
# 7   2499774        112
# 8   2621625        109
# 9     77151        109

# %%
freq_commandes = list(commandes_counts.order_id)
commandes_selected = commandes[commandes.order_id.isin(freq_commandes)].reset_index(drop=True)
commandes_selected.head(3)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0       106        4210                  1          0
# 1       106       11210                  2          0
# 2       106        2839                  3          1

# %%
commandes_selected.shape
# Out:
# (3426742, 4)

# %% [markdown]
# ### Sélection des produits les plus achetés

# %%
selected_p=100
produits_counts = commandes_selected.groupby('product_id')['order_id'].count().reset_index().rename(columns = {'order_id':'frequence'})
produits_counts = produits_counts.sort_values('frequence', ascending=False)[:selected_p].reset_index(drop=True)
produits_counts.head(10)
# Out:
#    product_id  frequence
# 0       24852      30893
# 1       13176      26536
# 2       21137      23769
# 3       21903      20101
# 4       47209      19999
# 5       26209      15407
# 6       27966      14952
# 7       47626      14823
# 8       47766      13786
# 9       22935      12218

# %%
freq_produits = list(produits_counts.product_id)
commandes_finales = commandes_selected[commandes_selected.product_id.isin(freq_produits)].reset_index(drop=True)
commandes_finales.shape
# Out:
# (713588, 4)

# %%
commandes_finales.head(3)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0       106       24184                 11          1
# 1       106       21938                 16          1
# 2       106       20114                 29          1

# %% [markdown]
# ### Récupération des noms de produits

# %%
produits=pd.read_csv('./products.csv',sep=',')
produits.head(3)
# Out:
#    product_id                          product_name  aisle_id  department_id
# 0           1            Chocolate Sandwich Cookies        61             19
# 1           2                      All-Seasons Salt       104             13
# 2           3  Robust Golden Unsweetened Oolong Tea        94              7

# %%
commandes_finales_produits = commandes_finales.merge(produits, on='product_id')
commandes_finales_produits.head(3)
# Out:
#    order_id  product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0       106       24184                 11          1  Red Peppers        83
# 1      1268       24184                 25          1  Red Peppers        83
# 2      1287       24184                 16          1  Red Peppers        83
#
#    department_id
# 0              4
# 1              4
# 2              4

# %% [markdown]
# ### Création du Data Frame pour la recherche de motifs et de Règles d'association

# %%
panier = commandes_finales_produits.pivot_table(columns='product_name', index='order_id', values='reordered',
                                       aggfunc='count').reset_index().fillna(0).set_index('order_id')
panier=panier.astype(int)

# %%
panier.head(3)
# Out:
# product_name  100% Whole Wheat Bread  Apple Honeycrisp Organic  Asparagus  \
# order_id
# 106                                0                         0          0
# 228                                0                         0          0
# 254                                1                         0          0
#
# product_name  Bag of Organic Bananas  Banana  Bartlett Pears  Blueberries  \
# order_id
# 106                                0       0               0            0
# 228                                1       0               0            0
# 254                                1       0               0            0
#
# product_name  Broccoli Crown  Bunched Cilantro  Cantaloupe  ...  \
# order_id                                                    ...
# 106                        0                 0           0  ...
# 228                        0                 0           0  ...
# 254                        0                 0           0  ...
#
# product_name  Shredded Parmesan  Small Hass Avocado  \
# order_id
# 106                           0                   0
# 228                           0                   0
# 254                           0                   0
#
# product_name  Sparkling Water Grapefruit  Strawberries  \
# order_id
# 106                                    0             0
# 228                                    0             0
# 254                                    0             0
#
# product_name  Total 2% with Strawberry Lowfat Greek Strained Yogurt  \
# order_id
# 106                                                           0
# 228                                                           0
# 254                                                           0
#
# product_name  Uncured Genoa Salami  Unsalted Butter  Unsweetened Almondmilk  \
# order_id
# 106                              0                0                       0
# 228                              0                0                       0
# 254                              0                0                       0
#
# product_name  Whipped Cream Cheese  Yellow Onions
# order_id
# 106                              0              0
# 228                              0              0
# 254                              0              0
#
# [3 rows x 100 columns]

# %% [markdown]
# ### Recherche de motifs fréquents

# %%
frequent_itemsets_train = apriori(panier, min_support=0.05, 
                                  use_colnames=True).sort_values(by='support', ascending=False)
frequent_itemsets_train
# Out:
#      support                                           itemsets
# 4   0.319047                                           (Banana)
# 3   0.274050                           (Bag of Organic Bananas)
# 47  0.245474                             (Organic Strawberries)
# 21  0.207593                             (Organic Baby Spinach)
# 36  0.206539                             (Organic Hass Avocado)
# ..       ...                                                ...
# 5   0.051131                                      (Blueberries)
# 17  0.050853                               (Orange Bell Pepper)
# 46  0.050285  (Organic Sticks Low Moisture Part Skim Mozzare...
# 74  0.050274        (Organic Raspberries, Organic Hass Avocado)
# 49  0.050006                  (Organic Unsweetened Almond Milk)
#
# [77 rows x 2 columns]

# %% [markdown]
# ### Recherche des règles d'association

# %%
training_rules = association_rules(frequent_itemsets_train, metric="confidence", min_threshold=0.2)
training_rules.sort_values(by=['confidence','lift'],ascending=False).iloc[:,:7]
# Out:
#                  antecedents               consequents  antecedent support  \
# 22            (Strawberries)                  (Banana)            0.116959
# 0     (Organic Hass Avocado)  (Bag of Organic Bananas)            0.206539
# 12     (Organic Raspberries)  (Bag of Organic Bananas)            0.154417
# 17         (Organic Avocado)                  (Banana)            0.142375
# 16             (Large Lemon)                  (Banana)            0.153084
# 20     (Organic Raspberries)    (Organic Strawberries)            0.154417
# 3     (Organic Strawberries)  (Bag of Organic Bananas)            0.245474
# 4     (Organic Hass Avocado)    (Organic Strawberries)            0.206539
# 9     (Organic Baby Spinach)  (Bag of Organic Bananas)            0.207593
# 1   (Bag of Organic Bananas)    (Organic Hass Avocado)            0.274050
# 23                   (Limes)                  (Banana)            0.159116
# 2   (Bag of Organic Bananas)    (Organic Strawberries)            0.274050
# 11    (Organic Baby Spinach)    (Organic Strawberries)            0.207593
# 24     (Organic Raspberries)    (Organic Hass Avocado)            0.154417
# 14    (Organic Baby Spinach)                  (Banana)            0.207593
# 5     (Organic Strawberries)    (Organic Hass Avocado)            0.245474
# 6     (Organic Strawberries)                  (Banana)            0.245474
# 18    (Organic Hass Avocado)    (Organic Baby Spinach)            0.206539
# 19    (Organic Baby Spinach)    (Organic Hass Avocado)            0.207593
# 10    (Organic Strawberries)    (Organic Baby Spinach)            0.245474
# 8   (Bag of Organic Bananas)    (Organic Baby Spinach)            0.274050
# 13  (Bag of Organic Bananas)     (Organic Raspberries)            0.274050
# 25    (Organic Hass Avocado)     (Organic Raspberries)            0.206539
# 21    (Organic Strawberries)     (Organic Raspberries)            0.245474
# 7                   (Banana)    (Organic Strawberries)            0.319047
# 15                  (Banana)    (Organic Baby Spinach)            0.319047
#
#     consequent support   support  confidence      lift
# 22            0.319047  0.055211    0.472053  1.479572
# 0             0.274050  0.092782    0.449222  1.639198
# 12            0.274050  0.067469    0.436932  1.594349
# 17            0.319047  0.061428    0.431452  1.352316
# 16            0.319047  0.062647    0.409229  1.282660
# 20            0.245474  0.057080    0.369650  1.505860
# 3             0.274050  0.089808    0.365855  1.334992
# 4             0.245474  0.074110    0.358818  1.461735
# 9             0.274050  0.071218    0.343068  1.251842
# 1             0.206539  0.092782    0.338559  1.639198
# 23            0.319047  0.053383    0.335497  1.051559
# 2             0.245474  0.089808    0.327706  1.334992
# 11            0.245474  0.067676    0.326004  1.328058
# 24            0.206539  0.050274    0.325575  1.576335
# 14            0.319047  0.063948    0.308044  0.965514
# 5             0.206539  0.074110    0.301906  1.461735
# 6             0.319047  0.072065    0.293576  0.920164
# 18            0.207593  0.059631    0.288714  1.390773
# 19            0.206539  0.059631    0.287249  1.390773
# 10            0.207593  0.067676    0.275695  1.328058
# 8             0.207593  0.071218    0.259873  1.251842
# 13            0.154417  0.067469    0.246194  1.594349
# 25            0.154417  0.050274    0.243412  1.576335
# 21            0.154417  0.057080    0.232530  1.505860
# 7             0.245474  0.072065    0.225876  0.920164
# 15            0.207593  0.063948    0.200434  0.965514

# %%
from prefixspan import PrefixSpan

# %%
db = [
    ['a','b', 'a', 'c', 'd'],
    ['a','b', 'c', 'd'],
    ['a','b', 'a', ],
    ['a','b', 'a', 'c', 'd'],
]

ps = PrefixSpan(db)

# %%
print(ps.topk(5,closed=True))
# Out:
# [(91, ['ADE']), (87, ['PH7']), (81, ['ADE', 'ADE']), (75, ['ADE', 'PH7']), (75, ['AMI'])]

# %%
print(ps.frequent(3, closed=True))
# Out:
# [(4, ['a', 'b']), (3, ['a', 'b', 'a']), (3, ['a', 'b', 'c', 'd']), (3, ['a', 'c', 'd'])]

# %%
print(ps.frequent(3, generator=True))
# Out:
# [(3, ['a', 'a']), (3, ['b', 'a']), (3, ['c']), (3, ['d'])]

# %%
import pickle

# %%
parcours=pickle.load(open('./parcours_final_0_6.pickle','rb'))

# %%
parcours=pickle.load(open('./parcours_final_0_6.pickle','rb'))
db=parcours[parcours.MATERNITE==1].ACTE[:100].tolist()

# %%
ps = PrefixSpan(db)

# %%
print(ps.topk(5))
# Out:
# [(91, ['ADE']), (87, ['PH7']), (81, ['ADE', 'ADE']), (75, ['ADE', 'PH7']), (75, ['AMI'])]

# %%
coverage = [[] for i in range(len(db))]

def cover(patt, matches):
    for i, _ in matches:
        coverage[i] = max(coverage[i], patt, key=len)


ps.topk(5, callback=cover)

print(coverage)
# Out:
# [['PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], [], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'PH7'], ['ADE', 'ADE'], ['PH7'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE'], ['ADE', 'ADE']]

# %%
ps = PrefixSpan(db)
print(ps.topk(5))
ps.minlen=4
print()
print(ps.topk(5))
# Out:
# [(91, ['ADE']), (87, ['PH7']), (81, ['ADE', 'ADE']), (75, ['ADE', 'PH7']), (75, ['AMI'])]
#
# [(54, ['AMI', 'MAU', 'AMI', 'MAU']), (52, ['ADE', 'ADE', 'AMI', 'MAU']), (49, ['ADE', 'AMI', 'MAU', 'ADE']), (49, ['AMI', 'MAU', 'ADE', 'ADE']), (48, ['AMI', 'MAU', 'ADE', 'AMI'])]

# %%
db=parcours[parcours.MATERNITE==1].ACTE.tolist()
ps = PrefixSpan(db)
ps.minlen=5
ps.maxlen=10

#liste_frequent=ps.frequent(45)
#print(liste_frequent)
#print(ps.topk(10))

print(ps.frequent(2000,generator=True))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <cell line: 10>()
#       4 ps.maxlen=10
#       6 #liste_frequent=ps.frequent(45)
#       7 #print(liste_frequent)
#       8 #print(ps.topk(10))
# ---> 10 print(ps.frequent(2000,generator=True))
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/frequent.py:65, in PrefixSpan_frequent(self, minsup, closed, generator, key, bound, filter, callback)
#      62 if key is None:
#      63     key = bound = PrefixSpan.defaultkey
# ---> 65 results = self._mine(frequent_rec)
#      67 return None if callback else results
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/prefixspan.py:17, in PrefixSpan._mine(self, func)
#      14 def _mine(self, func: Callable[[Pattern, Matches], None]) -> Any:
#      15     self._results.clear()
# ---> 17     func([], [(i, -1) for i in range(len(self._db))])
#      19     return self._results
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/frequent.py:57, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      52     if canpass(bound(newpatt, newmatches)) or\
#      53         (closed and canclosedprune(self._db, newpatt, newmatches)) or\
#      54             (generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)):
#      55         continue
# ---> 57     frequent_rec(newpatt, newmatches)
#      59 if generator:
#      60     occursstack.pop()
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/frequent.py:57, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      52     if canpass(bound(newpatt, newmatches)) or\
#      53         (closed and canclosedprune(self._db, newpatt, newmatches)) or\
#      54             (generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)):
#      55         continue
# ---> 57     frequent_rec(newpatt, newmatches)
#      59 if generator:
#      60     occursstack.pop()
#
#     [... skipping similar frames: PrefixSpan_frequent.<locals>.frequent_rec at line 57 (1 times)]
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/frequent.py:57, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      52     if canpass(bound(newpatt, newmatches)) or\
#      53         (closed and canclosedprune(self._db, newpatt, newmatches)) or\
#      54             (generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)):
#      55         continue
# ---> 57     frequent_rec(newpatt, newmatches)
#      59 if generator:
#      60     occursstack.pop()
#
# File ~/miniforge3/lib/python3.8/site-packages/prefixspan/frequent.py:45, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      42     if len(patt) == self.maxlen:
#      43         return
# ---> 45 occurs = nextentries(self._db, matches)
#      46 if generator:
#      47     occursstack.append(occurs)
#
# File ~/miniforge3/lib/python3.8/site-packages/extratools/dicttools.py:66, in nextentries(data, entries)
#      65 def nextentries(data: Sequence[Sequence[T]], entries: Entries) -> Mapping[T, Entries]:
# ---> 66     return invertedindex(
#      67         (data[i][lastpos + 1:] for i, lastpos in entries),
#      68         entries
#      69     )
#
# File ~/miniforge3/lib/python3.8/site-packages/extratools/dicttools.py:52, in invertedindex(seqs, entries)
#      49 def invertedindex(seqs: Iterable[Sequence[T]], entries: Entries = None) -> Mapping[T, Entries]:
#      50     index: Mapping[T, Entries] = defaultdict(list)
# ---> 52     for k, seq in enumerate(seqs):
#      53         i, lastpos = entries[k] if entries else (k, -1)
#      55         for p, item in enumerate(seq, start=(lastpos + 1)):
#
# File ~/miniforge3/lib/python3.8/site-packages/extratools/dicttools.py:67, in <genexpr>(.0)
#      65 def nextentries(data: Sequence[Sequence[T]], entries: Entries) -> Mapping[T, Entries]:
#      66     return invertedindex(
# ---> 67         (data[i][lastpos + 1:] for i, lastpos in entries),
#      68         entries
#      69     )
#
# KeyboardInterrupt:

# %%
db[0]
# Out:
# ['PH7',
#  'TB',
#  'TB',
#  'ATU',
#  'G',
#  'PH2',
#  'TB',
#  'ATU',
#  'G',
#  'PMR',
#  'HN',
#  'TB',
#  'PH4']

# %%
coverage = [[] for i in range(len(db))]

def cover(patt, matches):
    for i, _ in matches:
        coverage[i] = max(coverage[i], patt, key=len)
        
ps.topk(10,callback=cover)
print(coverage)
# Out:
# [[], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['ADE', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'ADE'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], [], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'ADE'], [], [], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI'], [], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['ADE', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'ADE'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'ADE', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], [], [], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI', 'MAU', 'AMI', 'MAU'], ['AMI', 'MAU', 'AMI',  ...
